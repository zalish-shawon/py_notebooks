# %% [markdown]
# # **List with Python**

# %%
numbers = [25, 32, 69, 56, 45]

print(numbers[2])

numbers[2] = 45

print(numbers)

numbers.append(100)

print(numbers)

numbers.pop()

print(numbers)
# Out:
# 69
# [25, 32, 45, 56, 45]
# [25, 32, 45, 56, 45, 100]
# [25, 32, 45, 56, 45]
