# %% [markdown]
# # **Text spliting and join formatting**

# %%
prompt = "What is Python Ai"

tokens = prompt.split()

sentence = "-".join(tokens)

print(type(tokens))
print(type(sentence))
# Out:
# <class 'list'>
# <class 'str'>
